# %%
import os
import numpy as np
import itertools as it
import pandas as pd
from types import SimpleNamespace
import matplotlib.pyplot as plt

# see https://stackoverflow.com/questions/41385708/multiprocessing-example-giving-attributeerror
# for why we use multiprocess rather than multiprocessing,
from multiprocess import Pool

import src.utils as utils
import src.initial as initial
import src.target as target
from src.proposals import norm
import src.mcmc as mcmc

utils.configure_pd(pd)
utils.configure_plt(plt)

# %%
# %%time

ell2 = 2.38**2
d_grid = list(np.linspace(1, 10, 10, dtype=int))
mode_pairs_grid = [('full_max_indep','na'),
                   ('full_max_refl','na'),
                   ('max_indep','same_u'),
                   ('max_indep','cond_same_u'),
                   ('max_refl','same_u'),
                   ('max_refl','cond_same_u')
]

# For paper, n_rep=1000. This take about 25 min running on 6 cores
# We iterate until meeting occurs, so n_iter = max iters to run each chain for
pl = utils.add_iter([{'n_rep':1000,
                      'n_iter':1000000,
                      'prop_mode':prop_mode, 'ar_mode':ar_mode,
                      'd':d, 'ell2':2.38**2}
                     for (d, (prop_mode, ar_mode)) in it.product(d_grid, mode_pairs_grid)])

def f(par):
    n = SimpleNamespace(**par)
    pr = f' - d = {n.d}, prop_mode = {n.prop_mode}, ar_mode = {n.ar_mode} ({n.i}/{n.i_total})'

    init = initial.Initialize(d=n.d, mode='target_indep')
    prop = norm.NormalProposal(d=n.d, sigma2=n.ell2/n.d, prop_mode=n.prop_mode)
    targ = target.NormalTarget(d=n.d, sigma2=1)

    cmh = mcmc.CoupledMH(init, prop, targ,
                         break_condition='meet', ar_mode=n.ar_mode)
    cmh.run(n_iter=n.n_iter, n_rep=n.n_rep, verbose=True, pr_postfix=pr)

    df0 = cmh.return_df()
    df0['mode'] = f'{n.prop_mode} {n.ar_mode}'
    return df0

df_list = []
with Pool(os.cpu_count()-2) as p:
    df_list += p.map(f, pl)

df = pd.concat(df_list)
# Out:
# 100 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 100 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 200 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 100 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 300 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 200 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 100 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 400 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 300 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 200 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 500 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 400 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 600 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 100 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)300 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
#
# 700 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 200 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 500 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 800 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 400 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 600 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 900 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 1000 - d = 1, prop_mode = full_max_indep, ar_mode = na (0/60)
# 700 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 100 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 500 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 300 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 800 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 600 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 200 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 900 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 1000 - d = 2, prop_mode = full_max_indep, ar_mode = na (6/60)
# 700 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 100 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 400 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 800 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 200 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 300 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 900 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 400 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 500 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 300 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 500 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 100 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 1000 - d = 3, prop_mode = full_max_indep, ar_mode = na (12/60)
# 200 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 600 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 600 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 200 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 700 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 400 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 800 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 300 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 900 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 700 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 400 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 1000 - d = 1, prop_mode = full_max_refl, ar_mode = na (1/60)
# 100 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 500 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 800 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 500 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 300 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 600 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 200 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 100 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 900 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 700 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 200 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 800 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 300 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 300 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 400 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 600 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 1000 - d = 1, prop_mode = max_indep, ar_mode = cond_same_u (3/60)
# 900 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 500 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 400 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 600 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 1000 - d = 2, prop_mode = full_max_refl, ar_mode = na (7/60)
# 700 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 400 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 500 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 800 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 100 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 900 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 200 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 300 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 700 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 1000 - d = 1, prop_mode = max_indep, ar_mode = same_u (2/60)
# 600 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 400 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 100 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 500 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 600 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 700 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 700 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 200 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 800 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 800 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 900 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 300 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 1000 - d = 1, prop_mode = max_refl, ar_mode = same_u (4/60)
# 800 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 500 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 100 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 400 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 900 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 500 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 200 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 900 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 600 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 1000 - d = 3, prop_mode = full_max_refl, ar_mode = na (13/60)
# 100 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 300 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 700 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 800 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 200 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 600 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 400 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 1000 - d = 2, prop_mode = max_indep, ar_mode = cond_same_u (9/60)
# 900 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 100 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 500 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 1000 - d = 2, prop_mode = max_indep, ar_mode = same_u (8/60)
# 300 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 100 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 600 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 200 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 400 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 200 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 700 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 300 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 700 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 500 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 300 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 400 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 800 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 500 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 600 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 600 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 400 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 700 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 900 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 800 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 700 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 500 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 900 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 1000 - d = 4, prop_mode = full_max_indep, ar_mode = na (18/60)
# 1000 - d = 2, prop_mode = max_refl, ar_mode = same_u (10/60)
# 800 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 800 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 600 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 900 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 700 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 100 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 1000 - d = 1, prop_mode = max_refl, ar_mode = cond_same_u (5/60)
# 100 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 800 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 100 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 900 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 900 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 200 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 1000 - d = 3, prop_mode = max_indep, ar_mode = same_u (14/60)
# 200 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 100 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 300 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 300 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 200 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 1000 - d = 3, prop_mode = max_indep, ar_mode = cond_same_u (15/60)
# 400 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 200 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 400 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 500 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 300 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 100 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 200 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 600 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 500 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 400 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 300 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 400 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 700 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 500 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 600 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 500 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 600 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 800 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 700 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 700 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 300 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 600 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 800 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 100 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 900 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 900 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 700 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 800 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 1000 - d = 3, prop_mode = max_refl, ar_mode = same_u (16/60)
# 1000 - d = 4, prop_mode = full_max_refl, ar_mode = na (19/60)
# 800 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 900 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 900 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 400 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 1000 - d = 2, prop_mode = max_refl, ar_mode = cond_same_u (11/60)
# 100 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 100 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 1000 - d = 5, prop_mode = full_max_indep, ar_mode = na (24/60)
# 200 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 200 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 100 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 300 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 500 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 100 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 200 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 400 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 300 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 200 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 200 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 500 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 400 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 300 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 300 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 600 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 600 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 400 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 700 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 500 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 400 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 500 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 800 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 300 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 600 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 900 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 500 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 600 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 700 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 700 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 1000 - d = 4, prop_mode = max_indep, ar_mode = same_u (20/60)
# 700 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 600 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 800 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 800 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 800 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 700 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 400 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 900 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 800 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 900 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 1000 - d = 5, prop_mode = full_max_refl, ar_mode = na (25/60)
# 900 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 900 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 1000 - d = 3, prop_mode = max_refl, ar_mode = cond_same_u (17/60)
# 1000 - d = 6, prop_mode = full_max_indep, ar_mode = na (30/60)
# 100 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 500 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 1000 - d = 4, prop_mode = max_indep, ar_mode = cond_same_u (21/60)
# 100 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 100 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 200 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 100 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 100 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 200 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 300 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 200 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 300 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 400 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 200 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 500 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 600 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 300 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 700 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 400 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 800 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 300 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 900 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 400 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 1000 - d = 4, prop_mode = max_refl, ar_mode = same_u (22/60)
# 500 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 600 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 400 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 500 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 200 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 600 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 100 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 600 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 500 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 700 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 200 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 700 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 700 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 800 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 600 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 800 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 300 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 900 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 900 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)700 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
#
# 1000 - d = 5, prop_mode = max_indep, ar_mode = same_u (26/60)
# 400 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 300 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 1000 - d = 6, prop_mode = full_max_refl, ar_mode = na (31/60)
# 800 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 800 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 500 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 900 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 100 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 600 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 1000 - d = 7, prop_mode = full_max_indep, ar_mode = na (36/60)
# 700 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 900 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 200 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 400 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 800 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 100 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 100 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 300 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 900 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 200 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 1000 - d = 5, prop_mode = max_indep, ar_mode = cond_same_u (27/60)
# 1000 - d = 4, prop_mode = max_refl, ar_mode = cond_same_u (23/60)
# 100 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 400 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 300 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 200 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 300 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 500 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 400 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 400 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 500 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 500 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 600 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 100 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 700 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 800 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 500 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 900 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 600 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 1000 - d = 5, prop_mode = max_refl, ar_mode = same_u (28/60)
# 600 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 200 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 700 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 600 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 100 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 700 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 300 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 800 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 200 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 200 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 800 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 900 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 900 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 300 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 400 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 1000 - d = 7, prop_mode = full_max_refl, ar_mode = na (37/60)
# 700 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 1000 - d = 6, prop_mode = max_indep, ar_mode = same_u (32/60)
# 400 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 500 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 500 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 100 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 600 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 600 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 300 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 200 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 800 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 700 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 700 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 300 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 800 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 800 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 900 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 400 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 900 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 900 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 1000 - d = 5, prop_mode = max_refl, ar_mode = cond_same_u (29/60)
# 400 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 500 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 1000 - d = 8, prop_mode = full_max_indep, ar_mode = na (42/60)
# 100 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 600 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 100 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 1000 - d = 6, prop_mode = max_indep, ar_mode = cond_same_u (33/60)
# 100 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 100 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 200 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 200 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 300 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 700 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 400 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 500 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 300 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 600 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 200 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 700 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 800 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 800 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 400 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 900 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 500 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 1000 - d = 6, prop_mode = max_refl, ar_mode = same_u (34/60)
# 500 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 900 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 300 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 100 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 600 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 200 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 1000 - d = 7, prop_mode = max_indep, ar_mode = same_u (38/60)
# 700 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 200 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 800 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 400 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 300 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 600 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 900 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 400 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 500 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 1000 - d = 8, prop_mode = full_max_refl, ar_mode = na (43/60)
# 500 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 600 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 600 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 100 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 700 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 700 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 300 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 700 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 800 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 900 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 200 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 800 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 1000 - d = 6, prop_mode = max_refl, ar_mode = cond_same_u (35/60)
# 800 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 900 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 300 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 100 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 1000 - d = 9, prop_mode = full_max_indep, ar_mode = na (48/60)
# 400 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 400 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 100 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 900 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 100 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 200 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 500 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 300 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 200 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 1000 - d = 7, prop_mode = max_indep, ar_mode = cond_same_u (39/60)
# 400 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 600 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 100 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 200 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 300 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 500 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 400 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 500 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 600 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 300 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 600 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 700 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 700 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 800 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 900 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 1000 - d = 7, prop_mode = max_refl, ar_mode = same_u (40/60)
# 500 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 700 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 800 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 100 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 800 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 400 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 900 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 200 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 200 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 1000 - d = 9, prop_mode = full_max_refl, ar_mode = na (49/60)
# 900 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 300 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 600 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 500 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 400 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 1000 - d = 8, prop_mode = max_indep, ar_mode = same_u (44/60)
# 500 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 100 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 600 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 600 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 700 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 700 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 800 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 200 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 700 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 900 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 300 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 1000 - d = 7, prop_mode = max_refl, ar_mode = cond_same_u (41/60)
# 800 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 300 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 800 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 900 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 400 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 1000 - d = 10, prop_mode = full_max_indep, ar_mode = na (54/60)
# 400 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 100 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 500 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 200 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 900 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 100 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 300 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 600 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 400 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 500 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 600 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 700 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 1000 - d = 8, prop_mode = max_indep, ar_mode = cond_same_u (45/60)
# 700 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 100 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 200 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 500 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 300 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 800 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 400 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 500 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 600 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 700 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 800 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 900 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 800 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 900 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 1000 - d = 8, prop_mode = max_refl, ar_mode = same_u (46/60)
# 1000 - d = 10, prop_mode = full_max_refl, ar_mode = na (55/60)
# 100 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 900 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 200 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 300 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 1000 - d = 9, prop_mode = max_indep, ar_mode = same_u (50/60)
# 400 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 100 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 200 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 500 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 600 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 600 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 700 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 800 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 200 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 900 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 1000 - d = 8, prop_mode = max_refl, ar_mode = cond_same_u (47/60)
# 700 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 300 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 400 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 800 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 300 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 500 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 900 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 600 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 700 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 400 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 1000 - d = 9, prop_mode = max_indep, ar_mode = cond_same_u (51/60)
# 100 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 200 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 800 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 300 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 400 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 500 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 600 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 700 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 800 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 900 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 1000 - d = 9, prop_mode = max_refl, ar_mode = same_u (52/60)
# 100 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 900 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 500 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 200 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 300 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 400 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 1000 - d = 10, prop_mode = max_indep, ar_mode = same_u (56/60)
# 500 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 600 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 700 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 800 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 900 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 1000 - d = 9, prop_mode = max_refl, ar_mode = cond_same_u (53/60)
# 600 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 700 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 800 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 900 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 1000 - d = 10, prop_mode = max_indep, ar_mode = cond_same_u (57/60)
# 100 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 200 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 300 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 400 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 500 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 600 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 700 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 800 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 900 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 1000 - d = 10, prop_mode = max_refl, ar_mode = same_u (58/60)
# 100 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 200 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 300 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 400 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 500 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 600 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 700 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 800 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 900 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# 1000 - d = 10, prop_mode = max_refl, ar_mode = cond_same_u (59/60)
# CPU times: user 1.37 s, sys: 1.06 s, total: 2.42 s
# Wall time: 25min 34s

# %%
#df.to_hdf('df_fig7.h5','df')

# process output
df_t = df.groupby(['d','rep_id','mode'])['t'].max().reset_index()
df_t = df_t.groupby(['d','mode'])[['t']]

df_avg = df_t.mean()#.reset_index()
df_avg['se'] = df_t.sem()
df_avg.reset_index(inplace=True)

df_avg = df_avg.pivot(index='d',columns='mode', values=['t','se'])
df_avg.loc[0] = 0.
df_avg = df_avg.reset_index()
df_avg.sort_values('d', inplace=True)

# %%
# Produce Figure 7: avg meeting time as a function of dimension and coupling

# Note that we want the order and labeling to be the same for all figures
mode_pairs = [
    ('max_indep same_u', r'$\bar{P}_{SQ}$ with $\bar{Q}_{MI}$'),
    ('max_refl same_u', r'$\bar{P}_{SQ}$ with $\bar{Q}_{MR}$'),
    ('full_max_indep na', r'$\bar{P}_{MI}$'),
    ('full_max_refl na', r'$\bar{P}_{MR}$'),
    ('max_indep cond_same_u', r'$\bar{P}_C$ with $\bar{Q}_{MI}$'),
    ('max_refl cond_same_u', r'$\bar{P}_C$ with $\bar{Q}_{MR}$')
]

mode_disp = [m[0] for m in mode_pairs]
mode_labs = [m[1] for m in mode_pairs]

mode_disp = [('t',m) for m in mode_disp]

df_avg.plot(x='d', y=mode_disp, marker='')

plt.annotate(r'Both $\bar{Q}_{MR}$ couplings',
             xy=(8.5, 22), xytext=(6.75, 0),
             arrowprops={'arrowstyle':'-','shrinkA':0, 'shrinkB':0})

plt.xlabel('Dimension')
plt.ylabel('Avg Meeting Time')
plt.legend(labels=mode_labs, ncol=1, title='Coupling')

#plt.savefig('meeting_times_labels.pdf')

plt.show()
